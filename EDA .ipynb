# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

# %%
data=pd.read_csv('/content/data_preprocses.csv')
data
# Out:
#       Unnamed: 0  brand  screen_size  screen_resolution            cpu  \
# 0              0   acer         15.6            2073600          amd_3
# 1              1   acer         15.6            2073600          amd_5
# 2              2   acer         15.6            2073600       intel_i7
# 3              3   acer         17.3            2073600       intel_i5
# 4              4   acer         14.0            2073600  intel_celeron
# ...          ...    ...          ...                ...            ...
# 2422        2430  apple         13.0            4096000       intel_i5
# 2423        2431  apple         15.0            4096000          apple
# 2424        2432  apple         13.0            4096000       intel_i5
# 2425        2433  apple         11.6            1049088       intel_i5
# 2426        2434  apple         13.3            1049088       intel_i5
#
#       cpu_speed   ram  memory     gpu gpu_description    OpSys  weight  \
# 0           4.1   8.0   128.0     amd      integrated  windows    3.92
# 1           4.3   8.0  1024.0     amd      integrated  windows    3.92
# 2           3.0  32.0  2048.0  nvidia       dedicated  windows    5.51
# 3           2.5  32.0  1024.0  nvidia       dedicated  windows    9.98
# 4           1.6   4.0    32.0   intel      integrated  windows    3.42
# ...         ...   ...     ...     ...             ...      ...     ...
# 2422        3.1   8.0   512.0   intel      integrated   mac_os    3.02
# 2423        3.5   8.0   512.0   apple      integrated   mac_os    6.35
# 2424        2.4   8.0   512.0   intel      integrated   mac_os    3.00
# 2425        2.7   4.0   128.0   intel      integrated   mac_os    1.10
# 2426        1.8   8.0   128.0   intel      integrated   mac_os    3.00
#
#        color    price         ppi
# 0     silver   292.49  141.211998
# 1       blue   669.99  141.211998
# 2      black  1869.00  141.211998
# 3      black  1159.00  127.335675
# 4     silver   293.00  157.350512
# ...      ...      ...         ...
# 2422    grey   744.40  232.221074
# 2423  silver  1439.95  201.258264
# 2424    grey   578.69  232.221074
# 2425  silver   209.99  135.094211
# 2426  silver   285.00  117.826530
#
# [2427 rows x 15 columns]

# %%
sns.displot(data=data, x="price", col="brand", kde=True,col_wrap=3)
plt.show()

# %%
sns.catplot(data=data, kind="bar", x="gpu", y="price", hue="gpu_description")
plt.show()

# %%
sns.barplot(x = data['gpu_description'], y = data['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = data['brand'], y = data['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = data['cpu'], y = data['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = data['screen_size'], y = data['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = data['screen_resolution'], y = data['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = data['cpu_speed'], y = data['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = data['ram'], y = data['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x = data['memory'], y = data['price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.countplot(data=data, x='gpu',hue='gpu_description')
plt.show()

# %%
# data.groupby('gpu').count('gpu_description')

# %%
def visualize_data(column):
  fig, axes = plt.subplots(1, 2,figsize=(15,5))
  sns.countplot(data=data, x=column,ax=axes[0])
  fig.suptitle("Visualize "+ column)
  axes[0].set_title("Number of records for each kind of "+column)
  axes[0].tick_params(labelrotation=90,axis='x')
  sns.barplot(data=data, y=column,x='price',ax=axes[1],orient='h')
  axes[1].set_title("Average price for each kind of "+column)
  plt.show()

# %%
visualize_data('brand')

# %%
visualize_data('cpu')

# %%
visualize_data('ram')

# %%
data.describe()
# Out:
#         Unnamed: 0  screen_size  screen_resolution    cpu_speed          ram  \
# count  2427.000000  2427.000000       2.427000e+03  2427.000000  2427.000000
# mean   1216.144623    14.961640       2.403296e+06     2.944693    19.346518
# std     702.450233     1.358813       1.387918e+06     1.721390    16.135754
# min       0.000000    11.000000       1.024000e+06     1.000000     2.000000
# 25%     608.500000    14.000000       2.073600e+06     2.100000     8.000000
# 50%    1215.000000    15.600000       2.073600e+06     2.800000    16.000000
# 75%    1823.500000    15.600000       2.304000e+06     3.900000    28.000000
# max    2434.000000    18.000000       9.216000e+06    65.000000   128.000000
#
#             memory       weight        price          ppi
# count  2427.000000  2427.000000  2427.000000  2427.000000
# mean    779.879687     4.211088   776.709374   153.300934
# std     747.106567     1.498514   550.925666    39.863845
# min      16.000000     0.010000    43.400000    90.583402
# 25%     256.000000     3.310000   377.000000   135.094211
# 50%     512.000000     3.930000   637.990000   141.211998
# 75%    1024.000000     4.955000  1038.455000   161.725391
# max    4096.000000    29.000000  4955.950000   400.528576

# %%
fig, axes = plt.subplots(1, 3,figsize=(15,5))
sns.countplot(data=data, x='gpu_description',ax=axes[0])
fig.suptitle("Visualize gpu_description")
axes[0].set_title("Number of records for each kind of gpu_description")
# axes[0].tick_params(labelrotation=90,axis='x')
sns.barplot(data=data, y='gpu_description',x='price',ax=axes[1],orient='h')
axes[1].set_title("Average price for each kind of gpu_description")
axes[1].tick_params(labelrotation=90,axis='y')
sns.countplot(data=data, x='gpu',hue='gpu_description',ax=axes[2])
plt.show()
